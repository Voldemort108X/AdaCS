# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %%
# !python voxelmorph_torch/train_2frame_covis_tv_alt.py --dataset 'CAMUS'  --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_alt_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 100  --warm_start --wandb-name 'vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_alt_debug' --alpha 0.04 --warm_start_epoch 1 --beta 5 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Result', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20240305_203617-v4lhpct2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_alt_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/v4lhpct2
# ...

# %%
# !python diffusemorph_torch/train_2frame_covis_tv_alt.py --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epoch 10 --lambda_L 20 --gamma 1 --warm_start --wandb-name 'dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt' --alpha 0.1 --warm_start_epoch 1 --beta 0.1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 24-03-05 22:49:50.511 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt/DiffuseMorph_2D_240305_224950/logs
#     tb_logger: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt/DiffuseMorph_2D_240305_224950/tb_logger
#     results: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt/DiffuseMorph_2D_240305_224950/results
#     checkpoint: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt/DiffuseMorph_2D_240305_224950/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_alt/DiffuseMorph_2D_240305_224950
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
# ...
