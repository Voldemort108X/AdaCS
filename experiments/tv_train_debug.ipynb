# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %% [markdown]
# # Voxelmorph

# %%
# !python voxelmorph_torch/train_2frame_covis_tv.py --dataset 'CAMUS'  --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 100  --warm_start --wandb-name 'vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_debug' --alpha 0.04 --warm_start_epoch 1 --beta 5 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_172429-bg0fy1p9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_CAMUS_2frame_covis_alpha_0.04_wse_20_tv_adabeta_5_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/bg0fy1p9
# ...

# %%
# !python voxelmorph_torch/train_2frame_covis_tv.py --dataset 'Echo'  --bidir --model-dir '../../Models/cvpr2024_covis/Echo/vxm_echo_2frame_covis_alpha_0.02_wse_10_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150 --warm_start --wandb-name 'vxm_echo_2frame_covis_alpha_0.02_wse_10_tv_adabeta_0.1_debug' --alpha 0.02 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_172538-154tupgg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_echo_2frame_covis_alpha_0.02_wse_10_tv_adabeta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/154tupgg
# ...

# %% [markdown]
# # Transmorph

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'ACDC'  --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 300  --warm_start --wandb-name 'tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_0.1_debug' --alpha 0.01 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_172642-cuzcxu0s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/cuzcxu0s
# Epoch 1/300 - 1.3974 sec/step - motion loss: 1.1547e-02  (5.7736e-03, 5.7736e-03, 1.2399e-11) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'CAMUS'  --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/tsm_CAMUS_2frame_covis_alpha_0.03_wse_20_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 5  --warm_start --wandb-name 'tsm_CAMUS_2frame_covis_alpha_0.03_wse_20_tv_adabeta_0.1_debug' --alpha 0.03 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_172758-alhhvz6p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_CAMUS_2frame_covis_alpha_0.03_wse_20_tv_adabeta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/alhhvz6p
# Epoch 1/5 - 1.6220 sec/step - motion loss: 9.8382e-03  (4.9191e-03, 4.9191e-03, 1.0449e-11) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'Echo'  --bidir --model-dir '../../Models/cvpr2024_covis/Echo/tsm_echo_2frame_covis_alpha_0.01_wse_20_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150  --warm_start --wandb-name 'tsm_echo_2frame_covis_alpha_0.01_wse_10_tv_adabeta_0.1_debug' --alpha 0.01 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_172914-ep2a47vv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_echo_2frame_covis_alpha_0.01_wse_10_tv_adabeta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/ep2a47vv
# Epoch 1/150 - 3.0882 sec/step - motion loss: 5.3209e-03  (2.6604e-03, 2.6604e-03, 3.8243e-11) - GPU Memory Allocated: 423.54 MB, Reserved: 2884.00 MB
# ...

# %% [markdown]
# # Diffusemorph

# %%
# !python diffusemorph_torch/train_2frame_covis_tv.py --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epoch 5 --lambda_L 20 --gamma 1 --warm_start --wandb-name 'dfm_ACDC_a2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug' --alpha 0.1 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 18:06:19.738 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180619/logs
#     tb_logger: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180619/tb_logger
#     results: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180619/results
#     checkpoint: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180619/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180619
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
# ...

# %%
# !python diffusemorph_torch/train_2frame_covis_tv.py --dataset 'CAMUS' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epoch 1 --lambda_L 20 --gamma 1 --warm_start --wandb-name 'dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug' --alpha 0.1 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 18:07:24.773 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180724/logs
#     tb_logger: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180724/tb_logger
#     results: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180724/results
#     checkpoint: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180724/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_debug/DiffuseMorph_2D_231108_180724
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
# ...

# %%
# !python diffusemorph_torch/train_2frame_covis_tv.py --dataset 'Echo' -p train -c diffusemorph_torch/config/diffuseMorph_train_3D.json --model-dir '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epoch 150 --lambda_L 20 --gamma 1 --warm_start --wandb-name 'dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug' --alpha 0.1 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 18:10:17.553 - INFO:   name: DiffuseMorph_3D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug/DiffuseMorph_3D_231108_181017/logs
#     tb_logger: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug/DiffuseMorph_3D_231108_181017/tb_logger
#     results: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug/DiffuseMorph_3D_231108_181017/results
#     checkpoint: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug/DiffuseMorph_3D_231108_181017/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1_debug/DiffuseMorph_3D_231108_181017
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: 3D
# ...
