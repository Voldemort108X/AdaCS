# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %% [markdown]
# # ACDC

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.01_wse_20' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.01_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.01_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_1_wse_20' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_1_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_1_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.5_wse_20' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.5_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.5_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.25_wse_20' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.25_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.25_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.5' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.5/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.5/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_1' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_1/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_1/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'ACDC' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/ACDC/test/' --result-dir '../../Results/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut' --model-motion '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# # CAMUS

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.1_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.25_wse_20' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.25_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.25_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20/I30000_E320_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.1' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.1/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.1/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.25' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.25/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.25/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.5' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.5/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_0.5/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1.5' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1.5/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_1.5/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_2.5' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_2.5/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_2.5/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %%
# !python diffusemorph_torch/test.py --dataset 'CAMUS' -p test -c diffusemorph_torch/config/diffuseMorph_test_2D.json --test-dir '../../Dataset/CAMUS/test/' --result-dir '../../Results/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5_nomut' --model-motion '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5_nomut/I28000_E300_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_alpha_0.5_wse_20_tv_adabeta_5_nomut/covis_0300.pt' --inshape 128 128
# Out:
# export CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# # Echo

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10/I15000_E160_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.1/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.25' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.25/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.25/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1.5' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1.5/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_1.5/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_2.5' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_2.5/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_2.5/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_5' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_5/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_5/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...

# %%
# !python diffusemorph_torch/test_resize.py --dataset 'Echo' -p test -c diffusemorph_torch/config/diffuseMorph_test_3D.json --test-dir '../../Dataset/Echo/test/' --result-dir '../../Results/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5_resize' --model-motion '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5/I14000_E150_gen_G.pth' --model-covis '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_alpha_0.1_wse_10_tv_adabeta_0.5/covis_0150.pt' --inshape 64 64 64
# Out:
# export CUDA_VISIBLE_DEVICES=0
# this is the info I need wmse
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# -------- Deform with eta=0.000
# -------- Deform with eta=0.167
# -------- Deform with eta=0.333
# -------- Deform with eta=0.500
# -------- Deform with eta=0.667
# -------- Deform with eta=0.833
# -------- Deform with eta=1.000
# ...
