# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %% [markdown]
# # Voxelmorph

# %%
# !python voxelmorph_torch/train_2frame_adareg.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/vxm_ACDC_2frame_adareg_debug' --motion-loss-type 'mse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'vxm_ACDC_2frame_adareg_debug' --steps-per-epoch 1 --c 50 --int-downsize 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231109_231033-48iqj1r8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_ACDC_2frame_adareg_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/48iqj1r8
# Epoch 1/10 - 1.2866 sec/step - motion loss: 9.4854e-03  (4.7427e-03, 4.7427e-03, 2.9528e-15) - GPU Memory Allocated: 3.91 MB, Reserved: 104.00 MB
# ...

# %%
# !python voxelmorph_torch/train_2frame_adareg.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/vxm_echo_2frame_adareg_debug' --motion-loss-type 'mse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'vxm_echo_2frame_adareg_debug' --steps-per-epoch 1 --c 50 --int-downsize 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231109_220435-2gjce07b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_echo_2frame_adareg_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/2gjce07b
# Epoch 1/10 - 3.9470 sec/step - motion loss: 5.5741e-03  (2.7870e-03, 2.7870e-03, 1.8048e-15) - GPU Memory Allocated: 61.51 MB, Reserved: 1940.00 MB
# ...

# %% [markdown]
# # Transmorph

# %%
# !python transmorph_torch/train_2frame_adareg.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_adareg_debug' --motion-loss-type 'mse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'tsm_ACDC_2frame_adareg_debug' --steps-per-epoch 1 --c 50
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231109_232159-hnd1mvf0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_adareg_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/hnd1mvf0
# Epoch 1/10 - 1.6743 sec/step - motion loss: 3.2407e-03  (1.6203e-03, 1.6203e-03, 1.3910e-11) - GPU Memory Allocated: 244.87 MB, Reserved: 448.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_adareg.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/tsm_Echo_2frame_adareg_debug' --motion-loss-type 'mse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'tsm_Echo_2frame_adareg_debug' --steps-per-epoch 1 --c 50
# Out:
# ^C
# Traceback (most recent call last):
#   File "transmorph_torch/train_2frame_adareg.py", line 9, in <module>
#     import torch
#   File "/home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/site-packages/torch/__init__.py", line 196, in <module>
#     _load_global_deps()
#   File "/home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/site-packages/torch/__init__.py", line 142, in _load_global_deps
#     if platform.system() == 'Windows' or sys.executable == 'torch_deploy':
#   File "/home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/platform.py", line 1068, in system
#     return uname().system
#   File "/home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/platform.py", line 1034, in uname
#     processor = _syscmd_uname('-p', '')
#   File "/home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/platform.py", line 791, in _syscmd_uname
#     output = f.read().strip()
# KeyboardInterrupt

# %% [markdown]
# # Diffusemorph

# %%
# !python diffusemorph_torch/train_2frame_adareg.py  --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json  --motion-loss-type 'adareg' --batch-size 8 --epoch 10 --accumulation_steps 2 --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug' --steps-per-epoch 1 --lambda_L 20 --gamma 1 --wandb-name 'dfm_ACDC_2frame_adareg_debug' --c 50
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-10 13:58:00.492 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug/DiffuseMorph_2D_231110_135800/logs
#     tb_logger: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug/DiffuseMorph_2D_231110_135800/tb_logger
#     results: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug/DiffuseMorph_2D_231110_135800/results
#     checkpoint: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug/DiffuseMorph_2D_231110_135800/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adareg_debug/DiffuseMorph_2D_231110_135800
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
#       dataroot: ./toy_sample/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 2
# ...

# %%
# !python diffusemorph_torch/train_2frame_adareg.py  --dataset 'Echo' -p train -c diffusemorph_torch/config/diffuseMorph_train_3D.json  --motion-loss-type 'adareg' --batch-size 8 --epoch 10 --accumulation_steps 2 --model-dir '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug' --steps-per-epoch 1 --lambda_L 20 --gamma 1 --wandb-name 'dfm_echo_2frame_adareg_debug' --c 50
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-10 13:59:24.122 - INFO:   name: DiffuseMorph_3D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug/DiffuseMorph_3D_231110_135923/logs
#     tb_logger: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug/DiffuseMorph_3D_231110_135923/tb_logger
#     results: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug/DiffuseMorph_3D_231110_135923/results
#     checkpoint: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug/DiffuseMorph_3D_231110_135923/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adareg_debug/DiffuseMorph_3D_231110_135923
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: 3D
#       dataroot: ./toy_sample/3d/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 3
# ...
