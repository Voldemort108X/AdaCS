# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %% [markdown]
# # Voxelmorph

# %%
# !python voxelmorph_torch/train_2frame_adaframe.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/vxm_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'vxm_ACDC_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_185052-2f39g1bb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_ACDC_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/2f39g1bb
# ...

# %%
# !python voxelmorph_torch/train_2frame_adaframe.py --dataset 'CAMUS' --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/vxm_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'vxm_CAMUS_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_211500-5inutn1e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_CAMUS_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/5inutn1e
# ...

# %%
# !python voxelmorph_torch/train_2frame_adaframe.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/vxm_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'vxm_Echo_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_211634-3m8ost5p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_Echo_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/3m8ost5p
# ...

# %% [markdown]
# # Transmorph

# %%
# !python transmorph_torch/train_2frame_adaframe.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'tsm_ACDC_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_212056-tpu3pxdk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/tpu3pxdk
# /home/xiaoranzhang/anaconda3/envs/optical_flow/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
# !python transmorph_torch/train_2frame_adaframe.py --dataset 'CAMUS' --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/tsm_CAMUS_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'tsm_CAMUS_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_212406-y4hc055h
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_CAMUS_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/y4hc055h
# Epoch 1/10 - 1.5594 sec/step - motion loss: 4.3090e-03  (2.1545e-03, 2.1545e-03, 1.0486e-11) - GPU Memory Allocated: 248.13 MB, Reserved: 452.00 MB
# Epoch 2/10 - 0.2959 sec/step - motion loss: 3.5402e-03  (1.7701e-03, 1.7701e-03, 1.0276e-11) - GPU Memory Allocated: 248.13 MB, Reserved: 516.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_adaframe.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/tsm_echo_2frame_adaframe_debug' --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --wandb-name 'tsm_echo_2frame_adaframe_debug' --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231108_212603-9wub6iyw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_echo_2frame_adaframe_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_cmp/runs/9wub6iyw
# Epoch 1/10 - 4.2740 sec/step - motion loss: 1.7246e-03  (8.6230e-04, 8.6230e-04, 3.1369e-11) - GPU Memory Allocated: 477.15 MB, Reserved: 2922.00 MB
# Epoch 2/10 - 2.1459 sec/step - motion loss: 1.9480e-03  (9.7398e-04, 9.7398e-04, 3.1910e-11) - GPU Memory Allocated: 478.07 MB, Reserved: 2930.00 MB
# ...

# %% [markdown]
# # Diffusemorph

# %%
# !python diffusemorph_torch/train_2frame_adaframe.py  --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json  --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_adaframe_debug' --steps-per-epoch 1 --lambda_L 20 --gamma 1 --wandb-name 'dfm_ACDC_2frame_adaframe_debug'
# Out:
# Traceback (most recent call last):
#   File "diffusemorph_torch/train_2frame_adaframe.py", line 84, in <module>
#     opt = Logger.parse(args)
#   File "/mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/diffusemorph_torch/core/logger.py", line 38, in parse
#     args.result_dir.replace('Results', 'Models'), '{}_{}'.format(opt['name'], get_timestamp()))
# AttributeError: 'Namespace' object has no attribute 'result_dir'

# %%
# !python diffusemorph_torch/train_2frame_adaframe.py  --dataset 'CAMUS' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json  --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --model-dir '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug' --steps-per-epoch 1 --lambda_L 20 --gamma 1 --wandb-name 'dfm_CAMUS_2frame_adaframe_debug'
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 22:26:45.955 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug/DiffuseMorph_2D_231108_222645/logs
#     tb_logger: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug/DiffuseMorph_2D_231108_222645/tb_logger
#     results: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug/DiffuseMorph_2D_231108_222645/results
#     checkpoint: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug/DiffuseMorph_2D_231108_222645/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_adaframe_debug/DiffuseMorph_2D_231108_222645
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
#       dataroot: ./toy_sample/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 2
# ...

# %%
# !python diffusemorph_torch/train_2frame_adaframe.py  --dataset 'Echo' -p train -c diffusemorph_torch/config/diffuseMorph_train_3D.json  --motion-loss-type 'wmse' --batch-size 8 --epoch 10 --accumulation_steps 2 --model-dir '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug' --steps-per-epoch 1 --lambda_L 20 --gamma 1 --wandb-name 'dfm_echo_2frame_adaframe_debug'
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 22:24:36.880 - INFO:   name: DiffuseMorph_3D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug/DiffuseMorph_3D_231108_222436/logs
#     tb_logger: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug/DiffuseMorph_3D_231108_222436/tb_logger
#     results: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug/DiffuseMorph_3D_231108_222436/results
#     checkpoint: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug/DiffuseMorph_3D_231108_222436/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_adaframe_debug/DiffuseMorph_3D_231108_222436
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: 3D
#       dataroot: ./toy_sample/3d/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 3
# ...
