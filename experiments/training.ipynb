# %%
# (Restart the kernel if you want to rerun the cell) move up current working directory
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis

# %% [markdown]
# # Voxelmorph

# %%
# !python voxelmorph_torch/train_2frame_covis_tv_nomut.py --dataset 'ACDC'  --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/vxm_ACDC_2frame_covis_alpha_0.02_wse_20_tv_adabeta_1.5_nomut_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 300  --warm_start --wandb-name 'vxm_ACDC_2frame_covis_alpha_0.02_wse_20_tv_adabeta_1.5_nomut_debug' --alpha 0.02 --beta 1.5  --warm_start_epoch 1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20240126_200453-zaarcfws
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_ACDC_2frame_covis_alpha_0.02_wse_20_tv_adabeta_1.5_nomut_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/zaarcfws
# ...

# %%
# !python voxelmorph_torch/train_2frame_covis.py --dataset 'Echo'  --bidir --model-dir '../../Models/cvpr2024_covis/Echo/vxm_echo_2frame_covis_alpha_0.01_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150 --steps-per-epoch 1  --warm_start --wandb-name 'vxm_echo_2frame_covis_alpha_0.01_debug'
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231030_115245-qzt4dm7u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_echo_2frame_covis_alpha_0.01_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/qzt4dm7u
# ...

# %%
# !python voxelmorph_torch/train_2frame_covis_tv.py --dataset 'ACDC'  --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/vxm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_beta_1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 300  --warm_start --wandb-name 'vxm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_beta_1_debug' --alpha 0.01 --beta 1  --warm_start_epoch 1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231107_104449-prpyab5a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_beta_1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/prpyab5a
# ...

# %%
# Out:
# python: can't open file 'voxelmorph_torch/train_2frame_covis_tv_nomut.py': [Errno 2] No such file or directory

# %%
# !python voxelmorph_torch/train_2frame_covis.py --dataset 'ACDC'  --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/vxm_ACDC_2frame_covis_alpha_0.01_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150 --steps-per-epoch 1  --warm_start --wandb-name 'vxm_ACDC_2frame_covis_alpha_0.01_debug'
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231031_120935-9ueanmfi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_ACDC_2frame_covis_alpha_0.01_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/9ueanmfi
# ...

# %%
# !python voxelmorph_torch/train_2frame_covis.py --dataset 'CAMUS'  --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/vxm_CAMUS_2frame_covis_alpha_0.01_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150 --steps-per-epoch 1  --warm_start --wandb-name 'vxm_CAMUS_2frame_covis_alpha_0.01_debug'
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231030_121320-ap2lh6y8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_CAMUS_2frame_covis_alpha_0.01_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/ap2lh6y8
# ...

# %%
# !python voxelmorph_torch/train_2frame_covis_tv.py --dataset 'Echo'  --bidir --model-dir '../../Models/cvpr2024_covis/Echo/vxm_Echo_2frame_covis_alpha_0.01_wse_20_tv_beta_0.1_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 300  --warm_start --wandb-name 'vxm_Echo_2frame_covis_alpha_0.01_wse_20_tv_beta_0.1_debug' --alpha 0.01 --beta 0.1  --warm_start_epoch 1 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231105_122709-i9yuj63y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vxm_Echo_2frame_covis_alpha_0.01_wse_20_tv_beta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/i9yuj63y
# ...

# %% [markdown]
# # Transmorph

# %%
# !python transmorph_torch/train_2frame_covis.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_ACDC_2frame_covis_debug_alpha_0.1_debug' --alpha 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231104_144837-nxqm78cp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_covis_debug_alpha_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/nxqm78cp
# Epoch 1/150 - 1.4736 sec/step - motion loss: 1.2715e-02  (6.3576e-03, 6.3577e-03, 1.0541e-11) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis.py --dataset 'CAMUS' --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/tsm_CAMUS_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_CAMUS_2frame_covis_debug_alpha_0.1_debug' --alpha 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231104_152131-vrpemwyw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_CAMUS_2frame_covis_debug_alpha_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/vrpemwyw
# Epoch 1/150 - 1.8374 sec/step - motion loss: 1.1694e-02  (5.8470e-03, 5.8470e-03, 9.0250e-12) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/tsm_echo_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_echo_2frame_covis_debug_alpha_0.1_debug' --alpha 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231104_152232-mfhm1k4c
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_Echo_2frame_covis_debug_alpha_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/mfhm1k4c
# Epoch 1/150 - 4.1528 sec/step - motion loss: 6.7092e-03  (3.3546e-03, 3.3546e-03, 2.4769e-11) - GPU Memory Allocated: 423.54 MB, Reserved: 2884.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'ACDC' --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_covis_tv_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_ACDC_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug' --alpha 0.1 --beta 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231105_172854-cn53foe0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/cn53foe0
# Epoch 1/150 - 2.0853 sec/step - motion loss: 5.9429e-03  (2.9714e-03, 2.9715e-03, 9.5453e-12) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'CAMUS' --bidir --model-dir '../../Models/cvpr2024_covis/CAMUS/tsm_CAMUS_2frame_covis_tv_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_CAMUS_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug' --alpha 0.1 --beta 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231105_172944-m17kg98z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_CAMUS_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/m17kg98z
# Epoch 1/150 - 1.6528 sec/step - motion loss: 1.0995e-02  (5.4977e-03, 5.4977e-03, 1.3247e-11) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv.py --dataset 'Echo' --bidir --model-dir '../../Models/cvpr2024_covis/Echo/tsm_Echo_2frame_covis_tv_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 150 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'tsm_Echo_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug' --alpha 0.1 --beta 0.1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20231105_173037-1hvmm9gj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_Echo_2frame_covis_debug_alpha_0.1_tv_beta_0.1_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/CVPR2024_covis
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/CVPR2024_covis/runs/1hvmm9gj
# Epoch 1/150 - 4.5469 sec/step - motion loss: 5.7017e-03  (2.8508e-03, 2.8508e-03, 2.7436e-11) - GPU Memory Allocated: 423.54 MB, Reserved: 2884.00 MB
# Epoch 2/150 - 2.6106 sec/step - motion loss: 6.2935e-03  (3.1468e-03, 3.1468e-03, 2.7994e-11) - GPU Memory Allocated: 423.27 MB, Reserved: 2892.00 MB
# ...

# %%
# !python transmorph_torch/train_2frame_covis_tv_nomut.py --dataset 'ACDC'  --bidir --model-dir '../../Models/cvpr2024_covis/ACDC/tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_1.5_nomut_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epochs 150  --warm_start --wandb-name 'tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_1.5_nomut_debug' --alpha 0.01 --warm_start_epoch 1 --beta 1.5 --steps-per-epoch 1
# Out:
# ['Code', 'Dataset', 'Models', 'Models_organizer', 'Results']
# wandb: Currently logged in as: voldemort108x (voldemort_team). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/wandb/run-20240127_105701-hcebpy4s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tsm_ACDC_2frame_covis_alpha_0.01_wse_20_tv_adabeta_1.5_nomut_debug
# wandb: ⭐️ View project at https://wandb.ai/voldemort_team/cvpr2024_covis_tv
# wandb: 🚀 View run at https://wandb.ai/voldemort_team/cvpr2024_covis_tv/runs/hcebpy4s
# Epoch 1/150 - 1.3661 sec/step - motion loss: 1.7265e-02  (8.6327e-03, 8.6328e-03, 1.3011e-11) - GPU Memory Allocated: 245.04 MB, Reserved: 450.00 MB
# ...

# %% [markdown]
# # Diffusemorph

# %%
# !python diffusemorph_torch/train_2frame_covis.py --dataset 'CAMUS' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/CAMUS/dfm_CAMUS_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 300 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'dfm_CAMUS_2frame_covis_debug_alpha_0.1_debug' --alpha 0.1 --warm_start_epoch 1 --lambda_L 20 --gamma 1
# Out:
# Traceback (most recent call last):
#   File "diffusemorph_torch/train_2frame_covis.py", line 87, in <module>
#     opt = Logger.parse(args)
#   File "/mnt/d/XiaoranZhang/Projects/Optical_flow/Code/cvpr2024_covis/diffusemorph_torch/core/logger.py", line 38, in parse
#     args.result_dir.replace('Results', 'Models'), '{}_{}'.format(opt['name'], get_timestamp()))
# AttributeError: 'Namespace' object has no attribute 'result_dir'

# %%
# !python diffusemorph_torch/train_2frame_covis.py --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 300 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'dfm_ACDC_2frame_covis_debug_alpha_0.1_debug' --alpha 0.1 --warm_start_epoch 1 --lambda_L 20 --gamma 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 14:36:57.840 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug/DiffuseMorph_2D_231108_143657/logs
#     tb_logger: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug/DiffuseMorph_2D_231108_143657/tb_logger
#     results: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug/DiffuseMorph_2D_231108_143657/results
#     checkpoint: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug/DiffuseMorph_2D_231108_143657/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_debug/DiffuseMorph_2D_231108_143657
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: Face
#       dataroot: ./toy_sample/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 2
# ...

# %%
# !python diffusemorph_torch/train_2frame_covis.py  --dataset 'Echo' -p train -c diffusemorph_torch/config/diffuseMorph_train_3D.json --model-dir '../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --epoch 300 --accumulation_steps 2 --steps-per-epoch 1  --warm_start --wandb-name 'dfm_echo_2frame_covis_debug' --alpha 0.1 --warm_start_epoch 1 --lambda_L 20 --gamma 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-11-08 14:51:59.541 - INFO:   name: DiffuseMorph_3D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug/DiffuseMorph_3D_231108_145159/logs
#     tb_logger: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug/DiffuseMorph_3D_231108_145159/tb_logger
#     results: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug/DiffuseMorph_3D_231108_145159/results
#     checkpoint: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug/DiffuseMorph_3D_231108_145159/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/Echo/dfm_echo_2frame_covis_debug/DiffuseMorph_3D_231108_145159
#   ]
#   datasets:[
#     centered: True
#     train:[
#       name: 3D
#       dataroot: ./toy_sample/3d/
#       batch_size: 1
#       num_workers: 8
#       use_shuffle: True
#     ]
#   ]
#   model:[
#     netDim: 3
# ...

# %%
# !python diffusemorph_torch/train_2frame_covis_tv_nomut.py --dataset 'ACDC' -p train -c diffusemorph_torch/config/diffuseMorph_train_2D.json --model-dir '../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug' --motion-loss-type 'wmse' --covis-loss-type 'coviswmse' --batch-size 8 --accumulation_steps 2 --epoch 300 --lambda_L 20 --gamma 1 --warm_start --wandb-name 'dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug' --alpha 0.1 --warm_start_epoch 1 --beta 0.1 --steps-per-epoch 1
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 24-01-27 11:25:00.393 - INFO:   name: DiffuseMorph_2D
#   phase: train
#   gpu_ids: [0]
#   display_port: 8097
#   path:[
#     log: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug/DiffuseMorph_2D_240127_112500/logs
#     tb_logger: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug/DiffuseMorph_2D_240127_112500/tb_logger
#     results: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug/DiffuseMorph_2D_240127_112500/results
#     checkpoint: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug/DiffuseMorph_2D_240127_112500/checkpoint
#     resume_state: None
#     experiments_root: ../../Models/cvpr2024_covis/ACDC/dfm_ACDC_2frame_covis_alpha_0.1_wse_20_tv_adabeta_0.1_nomut_debug/DiffuseMorph_2D_240127_112500
#   ]
#   datasets:[
#     centered: True
# ...
